# %%
from pathlib import Path
import os

from semconstmining.config import Config
from semconstmining.main import get_resource_handler

conf = Config(Path(os.getcwd()).parents[1].resolve(), "sap_sam_2022")

resource_handler = get_resource_handler(conf)
# Out:
# [2023-04-20 15:27:22,634] p27767 {bert_wrapper.py:239} INFO - loading serialized model
# [2023-04-20 15:27:23,806] p27767 {bert_wrapper.py:247} INFO - model loaded
# [2023-04-20 15:27:24,356] p27767 {keyedvectors.py:1954} INFO - loading projection weights from /Users/i585907/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz
# [2023-04-20 15:27:34,959] p27767 {utils.py:447} INFO - KeyedVectors lifecycle event {'msg': 'loaded (400000, 50) matrix of type float32 from /Users/i585907/gensim-data/glove-wiki-gigaword-50/glove-wiki-gigaword-50.gz', 'binary': False, 'encoding': 'utf8', 'datetime': '2023-04-20T15:27:34.959751', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 18:29:29) \n[Clang 12.0.0 ]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'load_word2vec_format'}
# [2023-04-20 15:27:34,961] p27767 {parser.py:168} INFO - Found 103 csvs
# [2023-04-20 15:27:34,962] p27767 {parser.py:72} INFO - Starting to parse 103 cvs
# ...
